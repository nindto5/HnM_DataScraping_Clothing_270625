# %% [markdown]
# **DATA CLEANING CLOTHING LADIES INDONESIA**

# %%
import pandas as pd

df = pd.read_csv('HnM_CLOTHING_LADIES_INDO.csv')

print(f"Initial number of columns: {df.shape[1]}")

null_percentages = df.isnull().sum() / len(df) * 100
threshold = 50

cleaned_columns = null_percentages[null_percentages > threshold].index

df_cleaned = df.drop(columns=cleaned_columns)
print(f"Number of columns after dropping those with >{threshold}% nulls: {df_cleaned.shape[1]}")


with pd.option_context('display.max_rows', 5, 'display.max_columns', None):
    display(df_cleaned)


print("\nColumns dropped and their null percentages:")
print(null_percentages[columns_to_drop])
# Out:
# Initial number of columns: 105
# Number of columns after dropping those with >50% nulls: 50
#              sku                    name  \
# 0     1297196002  Oversized poplin shirt
# 1     1294598001   Wide High Ankle Jeans
# ...          ...                     ...
# 4087  1269502017   Text-motif sweatshirt
# 4088  1290172002        Denim midi skirt
#
#                                           canonical_url  product_id      uid  \
# 0     //id.hm.com/id_en/oversized-poplin-shirt-12971...     3516934  3516934
# 1     //id.hm.com/id_en/wide-high-ankle-jeans-129459...     3453538  3453538
# ...                                                 ...         ...      ...
# 4087  //id.hm.com/id_en/text-motif-sweatshirt-126950...     3509061  3509061
# 4088  //id.hm.com/id_en/denim-midi-skirt-1290172002....     3575311  3575311
#
#       in_stock                                   description_html  \
# 0         True  Oversized shirt in crisp cotton poplin with a ...
# 1         True  Jeans in cotton denim with a slight stretch fo...
# ...        ...                                                ...
# 4087      True  Oversized top in sweatshirt fabric with a soft...
# 4088      True  Calf-length, A-line skirt in rigid cotton deni...
#
#       short_description_html  \
# 0     Oversized poplin shirt
# 1      Wide High Ankle Jeans
# ...                      ...
# 4087   Text-motif sweatshirt
# 4088        Denim midi skirt
#
#                                          all_image_data  final_price_value  \
# 0     [{"url": "//id.hm.com/id_en/media/catalog/prod...           399900.0
# 1     [{"url": "//id.hm.com/id_en/media/catalog/prod...           699900.0
# ...                                                 ...                ...
# 4087  [{"url": "//id.hm.com/id_en/media/catalog/prod...           499900.0
# 4088  [{"url": "//id.hm.com/id_en/media/catalog/prod...           599900.0
#
#      final_price_currency  regular_price_value regular_price_currency  \
# 0                     IDR             399900.0                    IDR
# 1                     IDR             699900.0                    IDR
# ...                   ...                  ...                    ...
# 4087                  IDR             499900.0                    IDR
# 4088                  IDR             599900.0                    IDR
#
#      agegroup article_description article_simple  articlenumber  \
# 0       Adult  Blue/White striped             no     1297196002
# 1       Adult               White             no     1294598001
# ...       ...                 ...            ...            ...
# 4087    Adult     Navy blue/Paris             no     1269502017
# 4088    Adult               White             no     1290172002
#
#      assortmenttype                                    careinstruction  color  \
# 0          Clothing  Can be dry cleaned,Machine wash at 40°,High ir...    0.0
# 1          Clothing  Can be dry cleaned,Machine wash at 30°,Medium ...    0.0
# ...             ...                                                ...    ...
# 4087       Clothing                                                NaN    0.0
# 4088       Clothing  Can be dry cleaned,Machine wash at 40°,Medium ...    0.0
#
#      color_description                                        composition  \
# 0                 Blue              {"":{"materials":{"cotton":"100.0"}}}
# 1                White  {"":{"materials":{"cotton":"99.0","elastane":"...
# ...                ...                                                ...
# 4087              Blue  {"":{"materials":{"cotton":"60.0","polyester":...
# 4088             White              {"":{"materials":{"cotton":"100.0"}}}
#
#      concept context customergroup  \
# 0        NaN  Casual         Women
# 1        NaN  Casual         Women
# ...      ...     ...           ...
# 4087     NaN  Casual         Women
# 4088     NaN  Casual         Women
#
#                                      descriptive_detail drycleaninstruction  \
# 0     94419124f973ced6851d3783cbe8e413778bb373_xxl-1...                 NaN
# 1     a341264e849ea46ee0ff8bca7543d9ec1681d9ed_xxl-1...                 NaN
# ...                                                 ...                 ...
# 4087  6d483d6abf36fa6d079f901f4d6a7f5ca6f4ba40_xxl-1...                 NaN
# 4088  6ba89b9e482444e116c4d643f429279ffd29761f_xxl-1...                 NaN
#
#               fit is_voucher          launch_date  \
# 0       Oversized         no  2025-06-23 00:00:00
# 1     Regular fit         no  2025-06-23 00:00:00
# ...           ...        ...                  ...
# 4087    Oversized         no  2025-06-13 00:00:00
# 4088  Regular fit         no  2025-06-09 00:00:00
#
#                                         lookbook_random newarrivals  \
# 0     5c2e3291a65ceac23fd1f942c550e5eaf7dfd50a_xxl-1...         yes
# 1     0d1ac1771ce1c6974b492cb1d149e77e412e8209_xxl-1...         yes
# ...                                                 ...         ...
# 4087  f55e5578a1f254ab850636ab154b388b327487c2_xxl-1...         yes
# 4088  3cdadd7e534310ce18a00240311a5809e1d4e4f8_xxl-1...         yes
#
#               online_date       pattern presentationproducttype  \
# 0     2025-06-23 00:00:00       Striped                   Shirt
# 1     2025-06-23 00:00:00  Solid colour                   Jeans
# ...                   ...           ...                     ...
# 4087  2025-06-13 00:00:00           NaN              Sweatshirt
# 4088  2025-06-09 00:00:00  Solid colour                   Skirt
#
#               retire_date      rgb sale short_product_name  size  \
# 0     9999-12-31 00:00:00  #2E5183   no              Shirt   0.0
# 1     9999-12-31 00:00:00  #EFEEEA   no              Jeans   0.0
# ...                   ...      ...  ...                ...   ...
# 4087  9999-12-31 00:00:00  #393A45   no         Sweatshirt   0.0
# 4088  9999-12-31 00:00:00  #EFEEEA   no              Skirt   0.0
#
#      sleeve_length  sleeve_style  \
# 0      Long sleeve           0.0
# 1              NaN           0.0
# ...            ...           ...
# 4087   Long sleeve           0.0
# 4088           NaN           0.0
#
#                                        stilllife_random      style  \
# 0     5c2e3291a65ceac23fd1f942c550e5eaf7dfd50a_xxl-1...        NaN
# 1     0d1ac1771ce1c6974b492cb1d149e77e412e8209_xxl-1...   Wide leg
# ...                                                 ...        ...
# 4087  f55e5578a1f254ab850636ab154b388b327487c2_xxl-1...  Crew-neck
# 4088  3cdadd7e534310ce18a00240311a5809e1d4e4f8_xxl-1...     A-line
#
#       stylenumber supplier_information              title_name  weight  \
# 0         1297196       Mainland China  Oversized poplin shirt     0.0
# 1         1294598           Bangladesh   Wide High Ankle Jeans     0.0
# ...           ...                  ...                     ...     ...
# 4087      1269502           Bangladesh   Text-motif sweatshirt     0.0
# 4088      1290172       Mainland China        Denim midi skirt     0.0
#
#       member_price presentationcolorgroup
# 0              NaN                    NaN
# 1              NaN                    NaN
# ...            ...                    ...
# 4087           NaN                    NaN
# 4088           NaN                    NaN
#
# [4089 rows x 50 columns]
# Columns dropped and their null percentages:
# discount_percent_off    100.000000
# discount_amount_off     100.000000
# barcodes                100.000000
# colection                97.236488
# color_name               96.991930
#                            ...
# skin_tone               100.000000
# skin_type               100.000000
# special_occasions       100.000000
# trademark               100.000000
# voucher_type            100.000000
# Length: 61, dtype: float64

# %%
output_filename = 'HnM_CLOTHING_LADIES_INDO_CLEANED.csv'
df_cleaned.to_csv(output_filename, index=False)

print(f"Successfully saved selected columns to '{output_filename}'")
# Out:
# Successfully saved selected columns to 'HnM_CLOTHING_LADIES_INDO_CLEANED.csv'
