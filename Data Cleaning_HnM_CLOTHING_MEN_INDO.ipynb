# %% [markdown]
# **DATA CLEANING CLOTHING MEN INDONESIA**

# %%
import pandas as pd

df = pd.read_csv('HnM_CLOTHING_MEN_INDO.csv')

print(f"Initial number of columns: {df.shape[1]}")

null_percentages = df.isnull().sum() / len(df) * 100
threshold = 50

cleaned_columns = null_percentages[null_percentages > threshold].index

df_cleaned = df.drop(columns=cleaned_columns)
print(f"Number of columns after dropping those with >{threshold}% nulls: {df_cleaned.shape[1]}")


with pd.option_context('display.max_rows', 5, 'display.max_columns', None):
    display(df_cleaned)


print("\nColumns dropped and their null percentages:")
print(null_percentages[cleaned_columns])
# Out:
# Initial number of columns: 105
# Number of columns after dropping those with >50% nulls: 48
#              sku                                  name  \
# 0     1271806002  Loose Fit Sleeveless printed T-shirt
# 1     1235413016                           Baggy Jeans
# ...          ...                                   ...
# 2628  1245480003                         Relaxed Jeans
# 2629  1172524001             Regular Fit lyocell shirt
#
#                                           canonical_url  product_id      uid  \
# 0     //id.hm.com/id_en/loose-fit-sleeveless-printed...     3363922  3363922
# 1         //id.hm.com/id_en/baggy-jeans-1235413016.html     3270191  3270191
# ...                                                 ...         ...      ...
# 2628    //id.hm.com/id_en/relaxed-jeans-1245480003.html     2346513  2346513
# 2629  //id.hm.com/id_en/regular-fit-lyocell-shirt-11...     1997061  1997061
#
#       in_stock                                   description_html  \
# 0         True  Sleeveless T-shirt in heavyweight cotton jerse...
# 1         True  5-pocket jeans in rigid cotton denim. Rounded ...
# ...        ...                                                ...
# 2628      True  5-pocket jeans in rigid cotton denim with a st...
# 2629      True  Regular-fit shirt in lyocell twill with a turn...
#
#                     short_description_html  \
# 0     Loose Fit Sleeveless printed T-shirt
# 1                              Baggy Jeans
# ...                                    ...
# 2628                         Relaxed Jeans
# 2629             Regular Fit lyocell shirt
#
#                                          all_image_data  final_price_value  \
# 0     [{"url": "//id.hm.com/id_en/media/catalog/prod...           299900.0
# 1     [{"url": "//id.hm.com/id_en/media/catalog/prod...           599900.0
# ...                                                 ...                ...
# 2628  [{"url": "//id.hm.com/id_en/media/catalog/prod...           499900.0
# 2629  [{"url": "//id.hm.com/id_en/media/catalog/prod...           230000.0
#
#      final_price_currency  regular_price_value regular_price_currency  \
# 0                     IDR             299900.0                    IDR
# 1                     IDR             599900.0                    IDR
# ...                   ...                  ...                    ...
# 2628                  IDR             499900.0                    IDR
# 2629                  IDR             599900.0                    IDR
#
#      agegroup article_description article_simple  articlenumber  \
# 0       Adult               White             no     1271806002
# 1       Adult          Denim blue             no     1235413016
# ...       ...                 ...            ...            ...
# 2628    Adult     Dark denim blue             no     1245480003
# 2629    Adult               Black             no     1172524001
#
#      assortmenttype                                    careinstruction  color  \
# 0          Clothing  No dry clean,Machine wash at 40°,Medium iron,O...    0.0
# 1          Clothing                                                NaN    0.0
# ...             ...                                                ...    ...
# 2628       Clothing                                                NaN    0.0
# 2629       Clothing  Can be dry cleaned,Machine wash at 30°,Medium ...    0.0
#
#      color_description                                        composition  \
# 0                White  {"shell":{"materials":{"cotton":"100.0"}},"nec...
# 1                 Blue  {"shell":{"materials":{"cotton":"100.0"}},"poc...
# ...                ...                                                ...
# 2628              Blue              {"":{"materials":{"cotton":"100.0"}}}
# 2629             Black                                                NaN
#
#      context customergroup                                 descriptive_detail  \
# 0     Casual           Men  b27c30c679015d4a8e83ebf85641024ed7a3c91e_xxl-1...
# 1     Casual           Men  c4bc012800e70d1b67889c64b93f64f561caa93f_xxl-1...
# ...      ...           ...                                                ...
# 2628  Casual           Men  f77f1bff51174b9a5876a141bc54773129f3926c_xxl-1...
# 2629  Casual           Man  f6d4aad2ff26be38b95f96c15ffe29bf96ce292a_xxl-1...
#
#      descriptivelength drycleaninstruction          fit is_voucher  \
# 0                  NaN                 NaN    Loose fit         no
# 1                 Long                 NaN    Loose fit         no
# ...                ...                 ...          ...        ...
# 2628              Long                 NaN  Relaxed fit         no
# 2629       Long sleeve  Can be dry cleaned  Regular fit         no
#
#               launch_date                                    lookbook_random  \
# 0     2025-04-14 00:00:00  eeda301cf57173f71f4188ac69ffbd785dfa92be_xxl-1...
# 1     2025-06-13 00:00:00  72d8a2c3a96148075346b66a397329913ef677b3_xxl-1...
# ...                   ...                                                ...
# 2628  2024-09-09 00:00:00  a91ea25f3415f4641b323bd74bb6983c8cc1f9a5_xxl-1...
# 2629  2024-12-18 00:00:00  c7b5f82954a2b48cda98f9b40f1bec3d4d3110e0_xxl-1...
#
#      newarrivals          online_date       pattern presentationproducttype  \
# 0            yes  2025-04-14 00:00:00  Solid colour                 T-shirt
# 1            yes  2025-06-13 00:00:00  Solid colour                   Jeans
# ...          ...                  ...           ...                     ...
# 2628          no  2024-09-09 00:00:00  Solid colour                   Jeans
# 2629          no  2024-05-01 00:00:00  Solid colour                   Shirt
#
#               retire_date      rgb sale short_product_name  size  \
# 0     9999-12-31 00:00:00  #F0EFEC   no            T-shirt   0.0
# 1     9999-12-31 00:00:00  #767F99   no              Jeans   0.0
# ...                   ...      ...  ...                ...   ...
# 2628  9999-12-31 00:00:00  #79829D   no              Jeans   0.0
# 2629  2099-12-31 00:00:00  #272628  yes              Shirt   0.0
#
#       sleeve_style                                   stilllife_random  \
# 0              0.0  8569aca9a8185911a1bf9b8fbae1214201d2c7d3_xxl-1...
# 1              0.0  c39093ffb835a463a896e042985967c886533dbc_xxl-1...
# ...            ...                                                ...
# 2628           0.0  a2f2bf1b4de276c9b4266110f717dd10c143eac3_xxl-1...
# 2629           0.0                                                NaN
#
#                  style  stylenumber supplier_information  \
# 0            Crew-neck      1271806       Mainland China
# 1                Baggy      1235413                India
# ...                ...          ...                  ...
# 2628      Straight leg      1245480           Bangladesh
# 2629  Turn-down collar      1172524                  NaN
#
#                                 title_name  weight presentationcolorgroup
# 0     Loose Fit Sleeveless printed T-shirt     0.0                    NaN
# 1                              Baggy Jeans     0.0                    NaN
# ...                                    ...     ...                    ...
# 2628                         Relaxed Jeans     0.0                   Blue
# 2629             Regular Fit lyocell shirt     0.0                  Black
#
# [2630 rows x 48 columns]
# Columns dropped and their null percentages:
# discount_percent_off        100.000000
# discount_amount_off         100.000000
# barcodes                     99.961977
# colection                    98.212928
# color_name                   95.247148
# concept                      69.391635
# designercollection          100.000000
# environment                  94.296578
# feature                      97.680608
# function                     91.901141
# heel_height                  99.429658
# measurementin_cm             72.433460
# member_price                 52.053232
# neckline                     70.494297
# occasion                     99.239544
# presentationproductgroup     85.475285
# product_safety_warning       98.060837
# quality                      96.311787
# shop_the_set                 66.311787
# sleeve_length                53.079848
# textual_print                88.935361
# trending                     76.577947
# visual_description           94.030418
# waist_rise                   75.893536
# washinginstruction           77.756654
# fragrancedescription        100.000000
# licensecompany              100.000000
# licenseitem                 100.000000
# featured                     71.330798
# family_json                  83.460076
# fast_selling                 53.650190
# promotion_label              87.034221
# accessory_style             100.000000
# benefit                     100.000000
# brand                       100.000000
# close                       100.000000
# collar                      100.000000
# colour                      100.000000
# concern                     100.000000
# coverage                    100.000000
# finish                      100.000000
# footwear_style              100.000000
# form                        100.000000
# fragrance_family            100.000000
# fragrance_name              100.000000
# hair_type                   100.000000
# key_ingredient              100.000000
# length                      100.000000
# material                    100.000000
# model                       100.000000
# primary_simple               96.501901
# skin_tone                   100.000000
# skin_type                   100.000000
# special_occasions           100.000000
# subordinate_articles         96.501901
# trademark                   100.000000
# voucher_type                100.000000
# dtype: float64

# %%
output_filename = 'HnM_CLOTHING_MEN_INDO_CLEANED.csv'
df_cleaned.to_csv(output_filename, index=False)

print(f"Successfully saved selected columns to '{output_filename}'")
# Out:
# Successfully saved selected columns to 'HnM_CLOTHING_MEN_INDO_CLEANED.csv'
