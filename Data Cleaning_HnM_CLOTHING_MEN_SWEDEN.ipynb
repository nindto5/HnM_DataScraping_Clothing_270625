# %% [markdown]
# **DATA CLEANING CLOTHING MEN SWEDEN**

# %%
import pandas as pd

df = pd.read_csv('HnM_CLOTHING_MEN_SWEDEN_020725.csv')

print(f"Initial number of columns: {df.shape[1]}")

null_percentages = df.isnull().sum() / len(df) * 100
threshold = 50

cleaned_columns = null_percentages[null_percentages > threshold].index

df_cleaned = df.drop(columns=cleaned_columns)
print(f"Number of columns after dropping those with >{threshold}% nulls: {df_cleaned.shape[1]}")


with pd.option_context('display.max_rows', 5, 'display.max_columns', None):
    display(df_cleaned)


print("\nColumns dropped and their null percentages:")
print(null_percentages[cleaned_columns])
# Out:
# Initial number of columns: 29
# Number of columns after dropping those with >50% nulls: 25
#               id         sku                                name brandName  \
# 0     1286182003  1286182003  Resortskjorta i linmix Regular Fit       H&M
# 1     1286183003  1286183003         Stickad T-shirt Regular Fit       H&M
# ...          ...         ...                                 ...       ...
# 2586   687336001   687336001        Tröja i ullmix med dragkedja     ARKET
# 2587   490418001   490418001        Finstickad tröja i merinoull     ARKET
#
#                                      url  \
# 0     /sv_se/productpage.1286182003.html
# 1     /sv_se/productpage.1286183003.html
# ...                                  ...
# 2586  /sv_se/productpage.0687336001.html
# 2587  /sv_se/productpage.0490418001.html
#
#                                           canonical_url  final_price_value  \
# 0     https://www2.hm.com/sv_se/productpage.12861820...              399.0
# 1     https://www2.hm.com/sv_se/productpage.12861830...              349.0
# ...                                                 ...                ...
# 2586  https://www2.hm.com/sv_se/productpage.06873360...              990.0
# 2587  https://www2.hm.com/sv_se/productpage.04904180...              690.0
#
#       regular_price_value  in_stock  coming_soon  \
# 0                   399.0      True        False
# 1                   349.0      True        False
# ...                   ...       ...          ...
# 2586                990.0      True        False
# 2587                690.0      True        False
#
#                                          all_image_data  \
# 0     [{"url": "https://image.hm.com/assets/hm/ee/0f...
# 1     [{"url": "https://image.hm.com/assets/hm/14/ec...
# ...                                                 ...
# 2586                                                 []
# 2587                                                 []
#
#                                             swatch_data colorName_main  \
# 0     [{"articleId": "1286182003", "url": "https://w...      Mörkbeige
# 1     [{"articleId": "1286183003", "url": "https://w...          Beige
# ...                                                 ...            ...
# 2586  [{"articleId": "0687336001", "url": "https://w...        Mörkblå
# 2587  [{"articleId": "0490418001", "url": "https://w...          Black
#
#      colourShades                                    available_sizes  \
# 0             NaN  [{"id": "002", "label": "S"}, {"id": "001", "l...
# 1             NaN  [{"id": "001", "label": "XS"}, {"id": "003", "...
# ...           ...                                                ...
# 2586          NaN  [{"id": "003", "label": "M"}, {"id": "002", "l...
# 2587       Kolgrå  [{"id": "001", "label": "XS"}, {"id": "002", "...
#
#                        mainCatCode  newArrival  isSale  \
# 0                men_shirts_casual        True   False
# 1     men_tshirtstanks_shortsleeve        True   False
# ...                            ...         ...     ...
# 2586  men_cardigansjumpers_jumpers       False   False
# 2587  men_cardigansjumpers_jumpers       False   False
#
#                                              modelImage  colors  \
# 0     https://image.hm.com/assets/hm/86/3d/863d5017d...  726A5D
# 1     https://image.hm.com/assets/hm/c3/a5/c3a51417e...  726A5D
# ...                                                 ...     ...
# 2586  https://image.hm.com/assets/006/4c/26/4c2603e9...  4C5164
# 2587  https://image.hm.com/assets/006/d0/40/d0406eec...  272628
#
#      supplier_country                                    supplier_name  \
# 0                Kina  Jiangsu Century Liaoyuan Knitted Wear Co., Ltd.
# 1                Kina  Jiangsu Century Liaoyuan Knitted Wear Co., Ltd.
# ...               ...                                              ...
# 2586              NaN                                              NaN
# 2587              NaN                                              NaN
#
#                                        factory_name  \
# 0     Jiangsu Century Liaoyuan Knitted Wear Co.Ltd.
# 1     Jiangsu Century Liaoyuan Knitted Wear Co.Ltd.
# ...                                             ...
# 2586                                            NaN
# 2587                                            NaN
#
#                                         factory_address factory_workers_number
# 0     No.168 Fangquan Road,, Juegang Town,, Rudong C...                101-500
# 1     No.168 Fangquan Road,, Juegang Town,, Rudong C...                101-500
# ...                                                 ...                    ...
# 2586                                                NaN                    NaN
# 2587                                                NaN                    NaN
#
# [2588 rows x 25 columns]
# Columns dropped and their null percentages:
# final_price_currency      100.000000
# regular_price_currency    100.000000
# colorCode_main            100.000000
# sellingAttribute           85.973725
# dtype: float64

# %%
output_filename = 'HnM_CLOTHING_MEN_SWEDEN_CLEANED.csv'
df_cleaned.to_csv(output_filename, index=False)

print(f"Successfully saved selected columns to '{output_filename}'")
# Out:
# Successfully saved selected columns to 'HnM_CLOTHING_MEN_SWEDEN_CLEANED.csv'
