# %% [markdown]
# **DATA REDUCTION CLOTHING LADIES INDONESIA**

# %%
import pandas as pd

df = pd.read_csv('HnM_CLOTHING_LADIES_INDO.csv')
with pd.option_context('display.max_rows', 5, 'display.max_columns', None): 
    display(df)
# Out:
#              sku                    name  \
# 0     1297196002  Oversized poplin shirt
# 1     1294598001   Wide High Ankle Jeans
# ...          ...                     ...
# 4087  1269502017   Text-motif sweatshirt
# 4088  1290172002        Denim midi skirt
#
#                                           canonical_url  product_id      uid  \
# 0     //id.hm.com/id_en/oversized-poplin-shirt-12971...     3516934  3516934
# 1     //id.hm.com/id_en/wide-high-ankle-jeans-129459...     3453538  3453538
# ...                                                 ...         ...      ...
# 4087  //id.hm.com/id_en/text-motif-sweatshirt-126950...     3509061  3509061
# 4088  //id.hm.com/id_en/denim-midi-skirt-1290172002....     3575311  3575311
#
#       in_stock                                   description_html  \
# 0         True  Oversized shirt in crisp cotton poplin with a ...
# 1         True  Jeans in cotton denim with a slight stretch fo...
# ...

# %%
columns_to_display = ['sku', 'name', 'product_id', 'final_price_value', 'final_price_currency', 'supplier_information']

df_selected_columns = df[columns_to_display]
display(df_selected_columns)
# Out:
#              sku                                              name  \
# 0     1297196002                            Oversized poplin shirt
# 1     1294598001                             Wide High Ankle Jeans
# 2     1260797016                                     Fine-knit top
# 3     1289496001                         Button-front sweater vest
# 4     1298699001                          Tailored denim waistcoat
# 5     1274171057                                   Printed T-shirt
# 6     1259779004                              Pleated denim shorts
# 7     1290170003                              Denim Bermuda shorts
# 8     1290276002                        Frill-trimmed denim blouse
# 9     1199191024                           Wide High Cropped Jeans
# 10    1283256005                             Smocked strappy dress
# 11    1292916003                           Interlock strappy dress
# 12    1289642004                            Short-sleeved cardigan
# ...

# %%
output_filename = 'HnM_CLOTHING_LADIES_INDO_REDUCED.csv'
df_selected_columns.to_csv(output_filename, index=False)

print(f"Successfully saved selected columns to '{output_filename}'")
# Out:
# Successfully saved selected columns to 'HnM_CLOTHING_LADIES_INDO_REDUCED.csv'
