# %% [markdown]
# **DATA REDUCTION CLOTHING MEN INDONESIA**

# %%
import pandas as pd

df = pd.read_csv('HnM_CLOTHING_MEN_USA_010725.csv')
with pd.option_context('display.max_rows', 5, 'display.max_columns', None): 
    display(df)
# Out:
#               id         sku                            name brandName  \
# 0     1292861001  1292861001  Slim-Fit Cable-Knit Polo Shirt       H&M
# 1     1290111001  1290111001   Regular-Fit Boxy Poplin Shirt       H&M
# ...          ...         ...                             ...       ...
# 1890  1008549029  1008549029          Straight Regular Jeans       H&M
# 1891  1008549030  1008549030          Straight Regular Jeans       H&M
#
#                                      url  \
# 0     /en_us/productpage.1292861001.html
# 1     /en_us/productpage.1290111001.html
# ...                                  ...
# 1890  /en_us/productpage.1008549029.html
# 1891  /en_us/productpage.1008549030.html
#
#                                           canonical_url  final_price_value  \
# 0     https://www2.hm.com/en_us/productpage.12928610...              44.99
# 1     https://www2.hm.com/en_us/productpage.12901110...              24.99
# ...                                                 ...                ...
# 1890  https://www2.hm.com/en_us/productpage.10085490...              39.99
# 1891  https://www2.hm.com/en_us/productpage.10085490...              39.99
#
#      final_price_currency  regular_price_value regular_price_currency  \
# 0                       $                44.99                      $
# 1                       $                24.99                      $
# ...                   ...                  ...                    ...
# 1890                    $                39.99                      $
# 1891                    $                39.99                      $
#
#       in_stock  coming_soon  \
# 0         True        False
# 1         True        False
# ...        ...          ...
# 1890      True        False
# 1891      True        False
#
#                                          all_image_data  \
# 0     [{"url": "https://image.hm.com/assets/hm/49/27...
# 1     [{"url": "https://image.hm.com/assets/hm/6b/14...
# ...                                                 ...
# 1890  [{"url": "https://image.hm.com/assets/hm/ae/98...
# 1891  [{"url": "https://image.hm.com/assets/hm/55/c7...
#
#                                             swatch_data      colorName_main  \
# 0     [{"articleId": "1292861001", "url": "https://w...               White
# 1     [{"articleId": "1290111001", "url": "https://w...  Light blue/striped
# ...                                                 ...                 ...
# 1890  [{"articleId": "1008549029", "url": "https://w...       Vintage black
# 1891  [{"articleId": "1008549030", "url": "https://w...    Light denim blue
#
#       colorCode_main                      colourShades  \
# 0                NaN                               NaN
# 1                NaN                               NaN
# ...              ...                               ...
# 1890             NaN                Charcoal|Dark gray
# 1891             NaN  Baby blue|Light blue|Pastel blue
#
#                                         available_sizes  \
# 0     [{"id": "007", "label": "3XL"}, {"id": "006", ...
# 1     [{"id": "007", "label": "3XL"}, {"id": "006", ...
# ...                                                 ...
# 1890  [{"id": "082", "label": "44/32"}, {"id": "044"...
# 1891  [{"id": "017", "label": "29/32"}, {"id": "037"...
#
#                 mainCatCode sellingAttribute  newArrival  isSale  \
# 0     MEN_TSHIRTSTANKS_POLO      New Arrival        True   False
# 1         men_shirts_casual      New Arrival        True   False
# ...                     ...              ...         ...     ...
# 1890      men_jeans_regular              NaN       False   False
# 1891      men_jeans_regular              NaN       False   False
#
#                                              modelImage  colors  \
# 0     https://image.hm.com/assets/hm/f8/0f/f80f8c8fd...  F1EEE6
# 1     https://image.hm.com/assets/hm/6f/6a/6f6a2c419...  B2BED9
# ...                                                 ...     ...
# 1890  https://image.hm.com/assets/hm/84/bc/84bc5bb42...  494A4F
# 1891  https://image.hm.com/assets/hm/23/1e/231eb4e98...  C8D0DB
#
#      supplier_country                  supplier_name  \
# 0               China  SUZHOU WANLI KNITTING CO.,LTD
# 1                 NaN                            NaN
# ...               ...                            ...
# 1890       Bangladesh            STERLING DENIMS LTD
# 1891       Bangladesh         SHIN SHIN APPARELS LTD
#
#                       factory_name  \
# 0     JUYE WANLI GARMENT CO., LTD.
# 1                              NaN
# ...                            ...
# 1890           Sterling Denim Ltd.
# 1891       SHIN SHIN APPARELS LTD.
#
#                                         factory_address factory_workers_number
# 0     North of Wanliu Road, 3 kilometers from West W...              1001-1500
# 1                                                   NaN                    NaN
# ...                                                 ...                    ...
# 1890               Dhania, Nayarhat, Savar, 1350, Dhaka              4001-4500
# 1891  Dag # RS 228, JL#73, Gorat,, East Norshinghapu...              1001-1500
#
# [1892 rows x 29 columns]

# %%
columns_to_display = ['sku', 'id', 'name', 'final_price_value', 'final_price_currency', 'supplier_country']

df_selected_columns = df[columns_to_display]
display(df_selected_columns)
# Out:
#              sku          id                            name  \
# 0     1292861001  1292861001  Slim-Fit Cable-Knit Polo Shirt
# 1     1290111001  1290111001   Regular-Fit Boxy Poplin Shirt
# 2     1292861003  1292861003  Slim-Fit Cable-Knit Polo Shirt
# 3     1275594004  1275594004             Slim-Fit Crop Pants
# 4     1292861002  1292861002  Slim-Fit Cable-Knit Polo Shirt
# ...          ...         ...                             ...
# 1887  1235414005  1235414005               Baggy Cargo Jeans
# 1888  1024256012  1024256012                      Slim Jeans
# 1889   979945046   979945046             Houston Loose Jeans
# 1890  1008549029  1008549029          Straight Regular Jeans
# 1891  1008549030  1008549030          Straight Regular Jeans
#
#       final_price_value final_price_currency supplier_country
# 0                 44.99                    $            China
# 1                 24.99                    $              NaN
# 2                 44.99                    $            China
# 3                 42.99                    $            India
# 4                 44.99                    $            China
# ...                 ...                  ...              ...
# 1887              42.99                    $       Bangladesh
# 1888              24.99                    $       Bangladesh
# 1889              49.99                    $       Bangladesh
# 1890              39.99                    $       Bangladesh
# 1891              39.99                    $       Bangladesh
#
# [1892 rows x 6 columns]

# %%
output_filename = 'HnM_CLOTHING_MEN_INDO_REDUCED.csv'
df_selected_columns.to_csv(output_filename, index=False)

print(f"Successfully saved selected columns to '{output_filename}'")
# Out:
# Successfully saved selected columns to 'HnM_CLOTHING_MEN_INDO_REDUCED.csv'
